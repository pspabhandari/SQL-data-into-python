# %% [markdown]
# postgres_user = 'dsbc_student'
# postgres_pw = '7*.8G9QH21'
# postgres_host = '142.93.121.174'
# postgres_port = '5432'
# postgres_db = 'dvdrentals'
#
# How many movies are released for each rating?
#
# What is the average rental duration for each rating?
#
# What is the mean movie length? Calculate this by defining a function.
#
# What is the median movie length? Calculate this by defining a function.
#
# Calculate the standard deviation of the movie lengths. Calculate this by defining a function.

# %%
# Import the SQL ALchemy engine
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

# %%
# Database credentials
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'dvdrentals'

# use the credentials to start a connection
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

# %%
#How many movies are released for each rating?
sql = '''
SELECT  COUNT(rating), rating
  FROM film
  GROUP BY rating;'''

results = engine.execute(sql)
engine.dispose()
rows = results.fetchall()

# print some results just to see what we got
for row in rows:
  print(row)
# Out:
# (195, 'R')
# (210, 'NC-17')
# (194, 'PG')
# (223, 'PG-13')
# (178, 'G')

# %%
#What is the average rental duration for each rating?
sql = '''
SELECT  ROUND(AVG(rental_duration), 1), rating
  FROM film
  GROUP BY rating;'''

results = engine.execute(sql)
engine.dispose()
rows = results.fetchall()

# print some results just to see what we got
for row in rows:
  print(row)
# Out:
# (Decimal('4.8'), 'R')
# (Decimal('5.1'), 'NC-17')
# (Decimal('5.1'), 'PG')
# (Decimal('5.1'), 'PG-13')
# (Decimal('4.8'), 'G')

# %%
#What is the mean movie length? Calculate this by defining a function.
sql = '''
SELECT  ROUND(AVG(length), 1)
  FROM film;'''

results = engine.execute(sql)
engine.dispose()
rows = results.fetchall()

# print some results just to see what we got
for row in rows:
  print(row)
# Out:
# (Decimal('115.3'),)

# %%
def mean(numbers):
    sum =  0
    for x in numbers:
        sum = sum + x
        n = len(numbers)
        mean = sum/n
    return mean

# %%
sql = '''
SELECT length
  FROM film
  ORDER BY length DESC;'''


results = engine.execute(sql)
engine.dispose()
rows = results.fetchall()

print(rows)
# Out:
# [(185,), (185,), (185,), (185,), (185,), (185,), (185,), (185,), (185,), (185,), (184,), (184,), (184,), (184,), (184,), (184,), (184,), (184,), (183,), (183,), (183,), (183,), (183,), (182,), (182,), (182,), (182,), (182,), (182,), (181,), (181,), (181,), (181,), (181,), (181,), (181,), (181,), (181,), (181,), (180,), (180,), (180,), (180,), (180,), (180,), (180,), (179,), (179,), (179,), (179,), (179,), (179,), (179,), (179,), (179,), (179,), (179,), (179,), (179,), (178,), (178,), (178,), (178,), (178,), (178,), (178,), (178,), (178,), (178,), (177,), (177,), (177,), (177,), (177,), (177,), (176,), (176,), (176,), (176,), (176,), (176,), (176,), (176,), (176,), (176,), (175,), (175,), (175,), (175,), (175,), (175,), (174,), (174,), (174,), (174,), (174,), (174,), (173,), (173,), (173,), (173,), (173,), (173,), (173,), (172,), (172,), (172,), (172,), (172,), (172,), (172,), (172,), (171,), (171,), (171,), (171,), (171,), (171,), (171,), (171,), (170,), (170,), (170,), (170,), (169,), (169,), (169,), (169,), (169,), (169,), (168,), (168,), (168,), (168,), (167,), (167,), (167,), (167,), (167,), (167,), (167,), (166,), (166,), (166,), (166,), (166,), (165,), (165,), (165,), (165,), (165,), (164,), (164,), (164,), (164,), (163,), (163,), (163,), (163,), (163,), (163,), (163,), (162,), (162,), (162,), (162,), (162,), (161,), (161,), (161,), (161,), (161,), (161,), (161,), (161,), (161,), (160,), (160,), (160,), (160,), (160,), (160,), (159,), (159,), (159,), (159,), (159,), (159,), (158,), (158,), (158,), (158,), (158,), (158,), (157,), (157,), (157,), (157,), (157,), (157,), (156,), (156,), (156,), (156,), (155,), (155,), (155,), (155,), (155,), (155,), (154,), (154,), (154,), (154,), (154,), (154,), (154,), (153,), (153,), (153,), (153,), (153,), (153,), (153,), (153,), (153,), (152,), (152,), (152,), (152,), (152,), (152,), (152,), (152,), (152,), (151,), (151,), (151,), (151,), (151,), (151,), (151,), (150,), (150,), (150,), (150,), (150,), (150,), (150,), (150,), (149,), (149,), (149,), (149,), (149,), (149,), (148,), (148,), (148,), (148,), (148,), (148,), (148,), (147,), (147,), (147,), (147,), (147,), (147,), (147,), (147,), (147,), (146,), (146,), (146,), (146,), (146,), (145,), (145,), (145,), (145,), (145,), (145,), (145,), (144,), (144,), (144,), (144,), (144,), (144,), (144,), (144,), (143,), (143,), (143,), (143,), (143,), (143,), (143,), (142,), (142,), (142,), (142,), (142,), (142,), (142,), (141,), (141,), (141,), (141,), (141,), (141,), (141,), (140,), (140,), (140,), (140,), (140,), (139,), (139,), (139,), (139,), (139,), (139,), (139,), (139,), (139,), (139,), (139,), (138,), (138,), (138,), (138,), (138,), (138,), (137,), (137,), (137,), (137,), (137,), (137,), (137,), (137,), (137,), (136,), (136,), (136,), (136,), (136,), (136,), (136,), (136,), (136,), (135,), (135,), (135,), (135,), (135,), (135,), (135,), (135,), (135,), (135,), (134,), (134,), (134,), (134,), (134,), (133,), (133,), (133,), (133,), (133,), (132,), (132,), (132,), (132,), (132,), (132,), (132,), (132,), (131,), (131,), (131,), (131,), (131,), (130,), (130,), (130,), (130,), (130,), (130,), (129,), (129,), (129,), (129,), (129,), (129,), (129,), (128,), (128,), (128,), (128,), (128,), (128,), (128,), (127,), (127,), (127,), (127,), (127,), (126,), (126,), (126,), (126,), (126,), (126,), (126,), (126,), (126,), (125,), (125,), (125,), (125,), (125,), (125,), (125,), (124,), (124,), (124,), (124,), (123,), (123,), (123,), (123,), (123,), (123,), (123,), (122,), (122,), (122,), (122,), (122,), (122,), (122,), (122,), (122,), (122,), (122,), (121,), (121,), (121,), (121,), (121,), (121,), (121,), (121,), (120,), (120,), (120,), (120,), (120,), (120,), (120,), (120,), (120,), (119,), (119,), (119,), (119,), (119,), (119,), (118,), (118,), (118,), (118,), (118,), (118,), (118,), (118,), (117,), (117,), (117,), (117,), (117,), (116,), (116,), (116,), (116,), (115,), (115,), (115,), (115,), (115,), (115,), (115,), (114,), (114,), (114,), (114,), ...

# %%
def mean(numbers):
    sum =  0
    for x in numbers:
        sum = sum + x
        n = len(numbers)
        mean = sum/n
    return mean

# %%
for x in rows:
    print(x[0])
# Out:
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 185
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 184
# 183
# 183
# 183
# 183
# 183
# 182
# 182
# 182
# 182
# 182
# 182
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 181
# 180
# 180
# 180
# 180
# 180
# 180
# 180
# 179
# 179
# 179
# 179
# 179
# 179
# 179
# 179
# 179
# 179
# 179
# 179
# 179
# 178
# 178
# 178
# 178
# 178
# 178
# 178
# 178
# 178
# 178
# 177
# 177
# 177
# 177
# 177
# 177
# 176
# 176
# 176
# 176
# 176
# 176
# 176
# 176
# 176
# 176
# 175
# 175
# 175
# 175
# 175
# 175
# 174
# 174
# 174
# 174
# 174
# 174
# 173
# 173
# 173
# 173
# 173
# 173
# 173
# 172
# 172
# 172
# 172
# 172
# 172
# 172
# 172
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 171
# 170
# 170
# 170
# 170
# 169
# 169
# 169
# 169
# 169
# 169
# 168
# 168
# 168
# 168
# 167
# 167
# 167
# 167
# 167
# 167
# 167
# 166
# 166
# 166
# 166
# 166
# 165
# 165
# 165
# 165
# 165
# 164
# 164
# 164
# 164
# 163
# 163
# 163
# 163
# 163
# 163
# 163
# 162
# 162
# 162
# 162
# 162
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 160
# 160
# 160
# 160
# 160
# 160
# 159
# 159
# 159
# 159
# 159
# 159
# 158
# 158
# 158
# 158
# 158
# 158
# 157
# 157
# 157
# 157
# 157
# 157
# 156
# 156
# 156
# 156
# 155
# 155
# 155
# 155
# 155
# 155
# 154
# 154
# 154
# 154
# 154
# 154
# 154
# 153
# 153
# 153
# 153
# 153
# 153
# 153
# 153
# 153
# 152
# 152
# 152
# 152
# 152
# 152
# 152
# 152
# 152
# 151
# 151
# 151
# 151
# 151
# 151
# 151
# 150
# 150
# 150
# 150
# 150
# 150
# 150
# 150
# 149
# 149
# 149
# 149
# 149
# 149
# 148
# 148
# 148
# 148
# 148
# 148
# 148
# 147
# 147
# 147
# 147
# 147
# 147
# 147
# 147
# 147
# 146
# 146
# 146
# 146
# 146
# 145
# 145
# 145
# 145
# 145
# 145
# 145
# 144
# 144
# 144
# 144
# 144
# 144
# 144
# 144
# 143
# 143
# 143
# 143
# 143
# 143
# 143
# 142
# 142
# 142
# 142
# 142
# 142
# 142
# 141
# 141
# 141
# 141
# 141
# 141
# 141
# 140
# 140
# 140
# 140
# 140
# 139
# 139
# 139
# 139
# 139
# 139
# 139
# 139
# 139
# 139
# 139
# 138
# 138
# 138
# 138
# 138
# 138
# 137
# 137
# 137
# 137
# 137
# 137
# 137
# 137
# 137
# 136
# 136
# 136
# 136
# 136
# 136
# 136
# 136
# 136
# 135
# 135
# 135
# 135
# 135
# 135
# 135
# 135
# 135
# 135
# 134
# 134
# 134
# 134
# 134
# 133
# 133
# 133
# 133
# 133
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 131
# 131
# 131
# 131
# 131
# 130
# 130
# 130
# 130
# 130
# 130
# 129
# 129
# 129
# 129
# 129
# 129
# 129
# 128
# 128
# 128
# 128
# 128
# 128
# 128
# 127
# 127
# 127
# 127
# 127
# 126
# 126
# 126
# 126
# 126
# 126
# 126
# 126
# 126
# 125
# 125
# 125
# 125
# 125
# 125
# 125
# 124
# 124
# 124
# 124
# 123
# 123
# 123
# 123
# 123
# 123
# 123
# 122
# 122
# 122
# 122
# 122
# 122
# 122
# 122
# 122
# 122
# 122
# 121
# 121
# 121
# 121
# 121
# 121
# 121
# 121
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 120
# 119
# 119
# 119
# 119
# 119
# 119
# 118
# 118
# 118
# 118
# 118
# 118
# 118
# 118
# 117
# 117
# 117
# 117
# 117
# 116
# 116
# 116
# 116
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 114
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 113
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 112
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 110
# 109
# 109
# 109
# 109
# 109
# 109
# 109
# 108
# 108
# 108
# 108
# 108
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 107
# 106
# 106
# 106
# 106
# 106
# 106
# 105
# 105
# 105
# 105
# 105
# 105
# 104
# 104
# 104
# 104
# 104
# 104
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 102
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 99
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 98
# 97
# 97
# 97
# 97
# 96
# 96
# 95
# 95
# 94
# 94
# 94
# 94
# 93
# 93
# 93
# 93
# 93
# 93
# 93
# 93
# 92
# 92
# 92
# 92
# 92
# 92
# 92
# 92
# 92
# 92
# 92
# 91
# 91
# 91
# 91
# 91
# 91
# 90
# 90
# 90
# 90
# 90
# 89
# 89
# 89
# 89
# 89
# 89
# 88
# 88
# 88
# 88
# 87
# 87
# 87
# 87
# 87
# 87
# 86
# 86
# 86
# 86
# 86
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 85
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 84
# 83
# 83
# 83
# 83
# 83
# 83
# 82
# 82
# 82
# 82
# 82
# 82
# 82
# 81
# 81
# 81
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 79
# 79
# 79
# 79
# 79
# 79
# 78
# 78
# 78
# 78
# 78
# 78
# 77
# 77
# 77
# 77
# 77
# 77
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 74
# 74
# 74
# 74
# 74
# 74
# 74
# 74
# 74
# 74
# 74
# 74
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 73
# 72
# 72
# 72
# 72
# 71
# 71
# 71
# 71
# 71
# 71
# 71
# 70
# 70
# 70
# 70
# 70
# 70
# 70
# 69
# 69
# 69
# 69
# 69
# 69
# 68
# 68
# 68
# 68
# 68
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 67
# 66
# 66
# 65
# 65
# 65
# 65
# 65
# 65
# 65
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 64
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 63
# 62
# 62
# 62
# 62
# 62
# 62
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 61
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 60
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 59
# 58
# 58
# 58
# 58
# 58
# 58
# 58
# 57
# 57
# 57
# 57
# 57
# 57
# 57
# 56
# 56
# 56
# 56
# 56
# 55
# 55
# 54
# 54
# 54
# 54
# 54
# 54
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 49
# 49
# 49
# 49
# 49
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 48
# 47
# 47
# 47
# 47
# 47
# 47
# 47
# 46
# 46
# 46
# 46
# 46

# %%
length = []
for x in rows:
    length.append(x[0])

# %%
mean(length)
# Out:
# 115.272

# %% [markdown]
# What is the median movie length? Calculate this by defining a function.

# %%
import math

def median(numbers):
  numbers.sort()  # sort the list of numbers
  count = len(numbers) # get the length of the array
  isEven = count % 2 == 0 # check if this list is of even length
  
  if (isEven):
    # find the two numbers in the middle of the array
    mid = math.floor( count / 2 )
    a = numbers[mid]
    b = numbers[mid + 1]
    # find the average of these two numbers
    ans = (a + b) / 2
  else:
    ans = numbers[math.floor( count / 2 )]
 
  return ans

# %%
median(length)
# Out:
# 114.0

# %% [markdown]
# Calculate the standard deviation of the movie lengths. Calculate this by defining a function.

# %%
def var(numbers):
    
    for x in numbers:
        n = len(numbers)
        var = (((x - mean(numbers)) ** 2)/(n-1))
    return var

# %%
var(length)
# Out:
# 4.866860844844844

# %%
from math import sqrt
def std(numbers):
    std = sqrt(var(numbers))
    return std

# %%
std(length)
# Out:
# 2.206096290927675
